# %%
from sklearn.datasets import make_classification
import pandas as pd

# %%
x, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_redundant=0,
    n_clusters_per_class=1,
    weights=[0.90],
    random_state=12
)

# %%
df1 = pd.DataFrame(x, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: imblearn in c:\users\itlas\appdata\roaming\python\python313\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (2.2.5)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (1.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\itlas\appdata\roaming\python\python313\site-packages (from imbalanced-learn->imblearn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
x, y = oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
y.shape
# Out:
# (1800,)

# %%
x.shape
# Out:
# (1800, 2)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
len(x[x==0])
# Out:
# 1800

# %%
len(x[x==1])
# Out:
# 1800

# %%
df1 = pd.DataFrame(x, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
oversample_df = pd.concat([df1, df2], axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
